# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os

# %%
df_bt = pd.read_excel('/home/zyj0704033/Voltage_Control/case_test/26batou.xlsx',header=None,usecols=[6,7])
df_wds = pd.read_excel('/home/zyj0704033/Voltage_Control/data/2015AGC/1wudengshan.xlsx',header=None)

# %%
plt.figure()
#random.randint(20000,30000)
plt.plot(range(len(df_bt[:1000][6])),df_bt[:1000][6]/df_bt[:1000][6].max())
plt.plot(range(len(df_wds[:1000][6])),df_wds[:1000][6]/df_wds[:1000][6].max())
plt.show()

# %%
dirpath = '/home/zyj0704033/Voltage_Control/data/2015AGC/'
if os.path.exists(dirpath):
    dirlist = os.path.listdir(dirpath)

# %%
df_bt[:1000][6].max()
# Out:
# 145.96000000000001
