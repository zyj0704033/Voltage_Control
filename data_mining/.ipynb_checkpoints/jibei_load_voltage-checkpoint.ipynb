# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pdv = pd.read_excel('/home/t630/Voltage_Control/data/load_data/3.沽源站数据（沽太出、汗沽入、变压器入）.xlsx',header = None)

# %%
# %matplotlib notebook
plt.plot(range(len(pdv.iloc[13][2:])),pdv.iloc[13][2:])
plt.plot(range(len(pdv.iloc[14][2:])),pdv.iloc[14][2:])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
l = [0]
pdv.iloc[13][2:]
temp = pdv.iloc[13][2]
for i in pdv.iloc[13][3:]:
    l.append(round(i-temp,1))
    temp = i

# %%
a = plt.hist(l)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
np.histogram(np.array(l))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-108dbc3fe185> in <module>()
# ----> 1 np.hist(np.array(l))
#
# AttributeError: 'module' object has no attribute 'hist'
