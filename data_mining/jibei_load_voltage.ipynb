# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pdv = pd.read_excel('/home/t630/Voltage_Control/data/load_data/3.沽源站数据（沽太出、汗沽入、变压器入）.xlsx',header = None)

# %%
# %matplotlib notebook
plt.plot(range(len(pdv.iloc[13][2:])),pdv.iloc[13][2:])
plt.plot(range(len(pdv.iloc[14][2:])),pdv.iloc[14][2:])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
l = [0]
pdv.iloc[13][2:]
temp = pdv.iloc[13][2]
for i in pdv.iloc[13][3:]:
    l.append(round(i-temp,1))
    temp = i

# %%
a = plt.hist(l)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
np.argwhere(np.array(l)>1.5).shape
# Out:
# (12, 1)

# %%
a
# Out:
# (array([   2.,   10.,   44.,  135.,  291.,  444.,  344.,  123.,   35.,   12.]),
#  array([-2.5 , -2.05, -1.6 , -1.15, -0.7 , -0.25,  0.2 ,  0.65,  1.1 ,
#          1.55,  2.  ]),
#  <a list of 10 Patch objects>)
